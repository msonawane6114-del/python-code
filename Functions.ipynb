# %%
def great():
    print('Hello how are you')
great()
# Out:
# Hello how are you

# %%
great()
# Out:
# Hello how are you

# %%
def square(num):
    result = num * num 
    print(result)

# %%
square(5)
# Out:
# 25

# %%
square(8)
# Out:
# 64

# %%
def square(num):
    """This is square function.
    you have to give input for num.
    It will return square of num"""
    result = num * num
    print(result)

# %%
square(93271)
# Out:
# 8699479441

# %%
def even_odd(num):
    if num % 2 == 0:
        print('Even', num)
    else:
        print('Odd',num)

# %%
even_odd(6)
# Out:
# Even 6

# %%
even_odd(9)
# Out:
# Odd 9

# %%
square(5)
# Out:
# 25

# %%
type(square(5))
# Out:
# 25
# NoneType

# %%
def new_square(num):
    result = num * num 
    return result

# %%
new_square(5)
# Out:
# 25

# %%
type(new_square(5))
# Out:
# int

# %%
def test2(n):
    for i in range(1,n):
        print(i)

# %%
test2(5)
# Out:
# 1
# 2
# 3
# 4

# %%
def test3(n):
    for i in range(1,n):
        return i

# %%
test3(5)
# Out:
# 1

# %%
def test4(n):
    l = [] # local variable
    for i in range(1,n):
        l.append(i)
    return l

# %%
test4(5)
# Out:
# [1, 2, 3, 4]

# %%
o = [1,2,3,4,5,6] # global

# %%
o
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
def test5(marks):
    if marks > 90:
        return 'A'
    elif marks > 50:
        return 'B'
    else:
        return 'fail'

# %%
test5(99)
# Out:
# 'A'

# %%
def sum_num(n):
    total = 0
    for i in range(1,n+1):
        total = total + i
    return total
sum_num(10)
# Out:
# 55

# %%
sum_num(5)
# Out:
# 15

# %%
def test5(a,b,c,d,r,t):
    return a,b,c,d,r,t

# %%
test5(1,6,4,2,6,5)
# Out:
# (1, 6, 4, 2, 6, 5)

# %%
def test6(*args):
    return args

# %%
test6(2,5,6, 'hello' ,True, 23,4,2,23)
# Out:
# (2, 5, 6, 'hello', True, 23, 4, 2, 23)

# %%
def test7(*args):
    l = []
    for i in args:
        if type(i) == int:
            l.append(i)
    return l
test7(2,5,6, 'hello',True,23,4,2,23)
# Out:
# [2, 5, 6, 23, 4, 2, 23]

# %%
# similar code for nested list, and you have to find out int type of data form list

# %%
1,1.5,True,[11,15.2,False],(12,12.6, 'python'),[10,20,10.5,[1,2,3,4,'hello']]
# Out:
# (1,
#  1.5,
#  True,
#  [11, 15.2, False],
#  (12, 12.6, 'python'),
#  [10, 20, 10.5, [1, 2, 3, 4, 'hello']])

# %%
def test8(a,b,*args):
    return a,b,args

# %%
test8(1,2,3,4,5,6,7,8,9,0)
# Out:
# (1, 2, (3, 4, 5, 6, 7, 8, 9, 0))

# %%
def test9(**kwargs):
    return kwargs

# %%
test9(a=5 ,b=10, c=11)
# Out:
# {'a': 5, 'b': 10, 'c': 11}

# %%
def test10(**kwargs):
    return kwargs.keys()

# %%
test10(a=5,b=10,c=11)
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
def test11(**kwargs):
    return kwargs.values()

# %%
test11(a=5,b=10,c=11)
# Out:
# dict_values([5, 10, 11])

# %%
def test11(*args,**kwargs):
    return args,kwargs

# %%
test11(1,2,453,23,23,23,21,a=5,b=10,c=11)
# Out:
# ((1, 2, 453, 23, 23, 23, 21), {'a': 5, 'b': 10, 'c': 11})

# %%
def test12(a,b,*args,**kwargs):
    return a,b,args,kwargs
test12(1,23,4,5,6,7,8,43,x=5,y=10,z=11)
# Out:
# (1, 23, (4, 5, 6, 7, 8, 43), {'x': 5, 'y': 10, 'z': 11})

# %%
def test12(*args,a,b,**kwargs):
    return a,b,args,kwargs
name = 'naman'
name[::-1]
# Out:
# 'naman'

# %%
name[::-1] == name
# Out:
# True
