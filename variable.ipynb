# %%
a = 5

# %%
a
# Out:
# 5

# %%
b = 1

# %%
b
# Out:
# 1

# %%
a+b
# Out:
# 6

# %%
type(b)
# Out:
# int

# %%
a*b
# Out:
# 5

# %%
c = a + b

# %%
c
# Out:
# 6

# %%
x,y,z = 10,20,30

# %%
x
# Out:
# 10

# %%
y
# Out:
# 20

# %%
z
# Out:
# 30

# %%
a5 = 120

# %%
a_5 = 120

# %%
a5
# Out:
# 120

# %%
a_5
# Out:
# 120

# %%
name = 'Mahi'
name
# Out:
# 'Mahi'

# %%
last_name = 'Sonawane'

# %%
last_name
# Out:
# 'Sonawane'

# %%
name + last_name
# Out:
# 'MahiSonawane'

# %%
type(name)
# Out:
# str

# %%
type ='Hello'

# %%
type
# Out:
# 'Hello'

# %% [markdown]
# # Operations

# %%
name
# Out:
# 'Mahi'

# %%
last_name
# Out:
# 'Sonawane'

# %%
name +' ' + last_name
# Out:
# 'Mahi Sonawane'

# %%
'5'
# Out:
# '5'

# %%
num = 5

# %%
num
# Out:
# 5

# %% [markdown]
# # Str ---> int

# %%
int(num)
# Out:
# 5

# %%
int(15.34556)
# Out:
# 15

# %%
float(5)
# Out:
# 5.0

# %% [markdown]
# # typecasting ---> changing one data type to another one

# %%
str(123)
# Out:
# '123'
