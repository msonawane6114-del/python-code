# %%
if 1 > 5:
    print(True)
else:
    print(False)
# Out:
# False

# %%
1 > 5
# Out:
# False

# %%
if 10 > 35:
    print('pass')
else:
    print('fail')
# Out:
# fail

# %%
marks = float(input('enter your marks'))

if marks > 35:
    print('pass')
else:
    print('fail')
# Out:
# enter your marks 34
# fail

# %%
marks = float(input('enter your marks'))

if marks >= 35:
    print('pass')
else:
    print('fail')
# Out:
# enter your marks 67
# pass

# %%
marks = float(input('enter your marks'))

if marks >= 90:
    print('A')
elif marks >= 70:
    print('B')
elif marks >= 50:
    print('C')
elif marks >= 35:
    print('pass')
else:
    print('fail')
# Out:
# enter your marks 87
# B

# %%
# COURSE INFO

# %%
course = input('enter your course name')

if course == 'python':
    print('yes we have python course')
elif course == 'java':
    print('we have java course')
else:
    print(f'we dont have {course} course.')
# Out:
# enter your course name java
# we have java course

# %%
'java' == 'python'
# Out:
# False

# %%
'java' == 'java'
# Out:
# True

# %%
'JAVA' .lower()
# Out:
# 'java'

# %%
'java' .lower()
# Out:
# 'java'

# %%
coupon = input('enter your coupon code')
total = float(input('enter your total bill'))

if coupon == ' DATA50':
    discount = total * 0.5
    print('f you will get discount of {discount}')
    final_price = print(f' your final total bill is {total - discount}')
elif coupon == 'DATA70':
    discount = total * 0.7
    print('f you will get discount of {discount}')
    final_price = print = print('f your final total bill is {total - discount}')
else:
    print('coupon code is not valid')
    print(f' your final price will be {total} $')
# Out:
# enter your coupon code 500
# enter your total bill 500
# coupon code is not valid
#  your final price will be 500.0 $

# %%
100 * 0.7
# Out:
# 70.0

# %%
100 * 0.5
# Out:
# 50.0

# %%
# similar code for course, discount

# %%
marks = float(input('enter your marks'))

if marks >= 90:
    print('A')
elif marks >= 70:
    print('B')
elif marks >= 50:
    print('C')
elif marks >= 35:
    print('pass')
else:
    print('fail')
# Out:
# enter your marks 76
# B

# %%
marks = float(input('Enter your marks'))

if marks >= 90 and marks <= 100: # True and False --->f
    print('A')
elif marks >= 70 and marks < 90: # True and False
    print('B')
elif marks >= 50 and marks < 70: # T and F
    print('C')
elif marks >= 35 and marks < 50: # T and F
    print('Pass')
elif marks >= 0 and marks < 35: # T and F
    print('Fail')
else:
    print('Please write marks between 0-100 range')
# Out:
# Enter your marks 23
# Fail

# %%
120 > 90 
120 >= 90 and 120 <= 100 # True and False 
120 >= 90
# Out:
# True

# %%
120 >= 90
# Out:
# True

# %%
120 <= 100
# Out:
# False

# %%
# even odd

# %%
10 % 2 # --> Even
# Out:
# 0

# %%
9 % 2 # --> Odd
# Out:
# 1

# %%
num = int(input('enter your num'))
if num % 2 == 0:
    print('even num',num)
elif num % 2 !=0:
    print('odd', num)
else:
    print('please rewrite num')
# Out:
# enter your num 6
# even num 6
