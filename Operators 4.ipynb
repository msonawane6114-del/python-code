# %%
True & True
# Out:
# True

# %%
True & False
# Out:
# False

# %%
False & True
# Out:
# False

# %%
False  & False
# Out:
# False

# %%
True & True
# Out:
# True

# %%
True - False
# Out:
# 1

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %%
5 > 1
# Out:
# True

# %%
5 > 5
# Out:
# False

# %%
5 < 5
# Out:
# False

# %%
5 >=5
# Out:
# True

# %%
5 >= 10
# Out:
# False

# %%
5 == 5
# Out:
# True

# %%
5 > 1 & 10 < 20 # True & True
# Out:
# True

# %%
'Hello' == 'hello'
# Out:
# False

# %%
a = 5

# %%
5 == 5
# Out:
# True

# %%
'exit' == 'exit'
# Out:
# True

# %%
'Hi' != 'By'
# Out:
# True

# %%
5 !=5
# Out:
# False

# %%
5 == 5
# Out:
# True

# %%
5 != 5
# Out:
# False

# %%
'Hello' != 'hello'
# Out:
# True

# %%
'exit' != 'exit'
# Out:
# False

# %%
'hi'
# Out:
# 'hi'

# %%
age  = 50

# %%
print('my age is' , age)
# Out:
# my age is 50

# %%
print(f'My age is {age} and i am very good person')
# Out:
# My age is 50 and i am very good person

# %%
name = 'xyz'

# %%
print(f'My name is {name} and my age is {age}')
# Out:
# My name is xyz and my age is 50

# %%
name = input('write your good name')
print(f'my name is {name}')
# Out:
# write your good name mahi
# my name is mahi

# %%
type(name)
# Out:
# str

# %%
age = int(input('enter your age'))
print(f' your age is {age}')
# Out:
# enter your age 55
#  your age is 55

# %%
type(age)
# Out:
# int

# %% [raw]
# # input --> str

# %%
student_name = input('enter student name')
marks = float(input('enter your marks'))
print(f'student name is {student_name} and marks are {marks} ')
# Out:
# enter student name 76
# enter your marks 45
# student name is 76 and marks are 45.0

# %% [markdown]
# # Data strectures

# %%
# list

# %%
l = [1,2,3,4,5]

# %%
l
# Out:
# [1, 2, 3, 4, 5]

# %%
mix = [1,15.2,10+5j, True, 'Hello']

# %%
mix
# Out:
# [1, 15.2, (10+5j), True, 'Hello']

# %%
type(mix)
# Out:
# list

# %%
names = ['om', 'sham', 'sham', 'ramesh']

# %%
names
# Out:
# ['om', 'sham', 'sham', 'ramesh']
