# %%
10+5
# Out:
# 15

# %%
10-5
# Out:
# 5

# %% [markdown]
# # First Day

# %% [markdown]
# today we are going to start python

# %% [markdown]
# # Heading

# %%
print(10 * 5)
# Out:
# 50

# %%
print(10 * 5)
print(10 - 5)
print(10 % 2)
# Out:
# 50
# 5
# 0
